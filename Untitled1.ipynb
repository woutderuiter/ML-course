# %%
# %matplotlib inline
from preamble import *
plt.rcParams['savefig.dpi'] = 100 # This controls the size of your figures
# Comment out and restart notebook if you only want the last output of each cell.
InteractiveShell.ast_node_interactivity = "all"

# %%
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
from sklearn.gaussian_process import GaussianProcessRegressor


ram_prices = pd.read_csv('data/ram_price.csv')

data_train = ram_prices[ram_prices.date < 2000]
data_test = ram_prices[ram_prices.date >= 2000]

X_train = data_train.date[:, np.newaxis]
y_train = np.log(data_train.price)

# %%
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9).fit(X_train, y_train)

X_all = ram_prices.date[:, np.newaxis]

pred_gp, sigma = gp.predict(X_all, return_std=True)

price_gp = np.exp(pred_gp)
#sigma_gp = np.exp(sigma)

plt.rcParams['lines.linewidth'] = 2
plt.semilogy(data_train.date, data_train.price, label="Training data")
plt.semilogy(data_test.date, data_test.price, label="Test data")
plt.semilogy(ram_prices.date, price_gp, label="Gaussian process prediction")
plt.fill(np.concatenate([ram_prices.date, ram_prices.date[::-1]]),
         np.concatenate([price_gp - 1.9600 * sigma,
                        (price_gp + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
plt.legend();

# %%
fig = plt.figure()
plt.plot(X_train, y_train, 'r.', markersize=10, label=u'Observations')
plt.plot(X_all, pred_gp, 'b-', label=u'Prediction')
plt.fill(np.concatenate([X_all, X_all[::-1]]),
         np.concatenate([pred_gp - 1.9600 * sigma,
                        (pred_gp + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.legend(loc='upper left')
# Out:
# (-10, 20)
